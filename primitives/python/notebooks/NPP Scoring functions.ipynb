# %% [markdown]
# # Scoring function Scratchpad
#
# Features
# 1. number of  common columns
# 2. avg, min and max value overlap ratios of common columns
# 3. maximum coherent overlap of value lattice of common columns, ratio
# 4. number of columns that exhibit coherent overlap when number 3 is above a certain threshold
# 5. number of columns that have unique values, that are non unique in the counterpart version.
# 6. contraction ratio of number of rows in original to grouped col attributes

# %%
# Imports and Environmental Setup

import sys
sys.path.insert(0, '..')

import warnings
from tqdm import TqdmExperimentalWarning
warnings.simplefilter('ignore', TqdmExperimentalWarning)

from tqdm.autonotebook import tqdm


import matplotlib
# %matplotlib inline

import ipywidgets 
import agglomerative

import numpy as np
import pandas as pd

from lineage import similarity, graphs

import itertools

# %%
base_dir = agglomerative.BASE_DIR
nb_name = agglomerative.NB_NAME
df_dict = similarity.load_dataset_dir(agglomerative.BASE_DIR+agglomerative.NB_NAME+'/artifacts/', '*.csv')

# %%
def common_columns(df1,df2):
    return set(df1).intersection(set(df2))

def get_col_valset(df):
    for col in set(df):
        yield col, set(df[col].values)

# %%
def compute_df_pair_features(df1,df2, df1_value_set_dict=None, df2_value_set_dict=None):
    common_cols = set(df1).intersection(set(df2))
    
    if not df1_value_set_dict:
        df1_value_set_dict = {name:valset for name, valset in get_col_valset(df1)}
    if not df2_value_set_dict:
        df2_value_set_dict = {name:valset for name, valset in get_col_valset(df2)}
    
    cell_jaccard = similarity.compute_jaccard_DF(df1,df2)
    col_jaccard = similarity.compute_col_jaccard_DF(df1,df2) #TODO: Use value set
    
    containment_scores  = [similarity.set_max_containment(df1_value_set_dict[col], 
                                                          df2_value_set_dict[col]) for col in common_cols]
    
    #Uniqueness computation
    unique_cols = 0
    contraction_ratios = []
    for col in common_cols:
        rows_not_equal = len(df1[col].values) != len(df2[col].values)
        df1_unique = len(df1_value_set_dict[col]) == len(df1[col])
        df2_unique = len(df2_value_set_dict[col]) == len(df2[col])
        
        df1_subset = df1_value_set_dict[col].issubset(df2_value_set_dict[col])
        df2_subset = df2_value_set_dict[col].issubset(df1_value_set_dict[col])
        
        if rows_not_equal and (df1_unique or df2_unique) and (df1_subset or df2_subset):
            unique_cols += 1
            numerator, denominator = max(len(df1[col]), len(df2[col])), min(len(df1[col]), len(df2[col]))
            contraction_ratios.append(numerator/denominator)
    
    result = {
        'common_cols' : len(common_cols),
        'cell_jaccard' : cell_jaccard,
        'col_jaccard' : col_jaccard,
        'unique_cols': unique_cols,
    }
    
    if containment_scores:
        result.update({
            'max_containment' : max(containment_scores),
            'avg_containment' : np.average(containment_scores),
            'min_containment' : min(containment_scores),
        })
        
    if contraction_ratios:
        result.update({
            'max_contraction' : max(contraction_ratios),
            'avg_contraction' : np.average(contraction_ratios),
            'min_contraction' : min(contraction_ratios), 
        })
        
    
    return result

# %%
compute_df_pair_features(df_dict['crimes.csv'], df_dict['crimeTypes.csv'])
# Out:
# {'common_cols': 6,
#  'cell_jaccard': 3.7355053055381854e-07,
#  'col_jaccard': 1.0,
#  'unique_cols': 1,
#  'max_containment': 1.0,
#  'avg_containment': 0.28205128205128205,
#  'min_containment': 0.0,
#  'max_contraction': 34320.692307692305,
#  'avg_contraction': 34320.692307692305,
#  'min_contraction': 34320.692307692305}

# %%
def get_all_node_pair_scores(dataset, gt_graph):
    pairwise_scores = []
    pairs = list(itertools.combinations(dataset.keys(), 2))
    df_value_dicts = {}
    for d1, d2 in tqdm(pairs, desc='graph pairs', leave=False):
        if d1 not in df_value_dicts.keys():
            df_value_dicts[d1] = {name:valset for name, valset in get_col_valset(dataset[d1])}
        if d2 not in df_value_dicts.keys():
            df_value_dicts[d2] = {name:valset for name, valset in get_col_valset(dataset[d2])}
        
        result = compute_df_pair_features(dataset[d1], dataset[d2], df1_value_set_dict=df_value_dicts[d1], 
                                          df2_value_set_dict=df_value_dicts[d2])
        
        gt = False
        
        if gt_graph.has_edge(d1, d2):
            result['operation'] = gt_graph[d1][d2]['operation']
            result['source'] = d1
            result['dest'] = d2
            gt=True
        elif gt_graph.has_edge(d2, d1):
            result['operation'] = gt_graph[d2][d1]['operation']
            result['source'] = d2
            result['dest'] = d1
            gt=True
     
        result['ground_truth'] = gt
        pairwise_scores.append(result)

    return pairwise_scores

# %%
gt_graph = graphs.get_graph(base_dir,nb_name)

# %%
data = get_all_node_pair_scores(df_dict, gt_graph)
# Out:
# HBox(children=(IntProgress(value=0, description='graph pairs', max=153), HTML(value='')))

# %%
pd.DataFrame(data)
# Out:
#      avg_containment  avg_contraction  cell_jaccard  col_jaccard  common_cols  \
# 0           0.282051     34320.692308  3.201862e-07     1.000000            6
# 1           0.230415              NaN  6.403723e-07     0.184971            6
# 2           0.309557              NaN  9.245376e-06     1.000000            5
# 3           0.277778     37180.750000  6.403723e-07     1.000000            6
# 4           0.425849              NaN  2.073205e-05     1.000000            6
# 5           0.252525              NaN  6.403723e-07     0.184971            6
# 6           0.235465      2594.005814  5.603258e-07     1.000000            6
# 7           1.000000              NaN  8.571429e-01     1.000000            6
# 8           0.252525              NaN  6.403723e-07     0.184971            6
# 9           0.425849              NaN  2.369378e-05     1.000000            6
# 10          0.111111              NaN  2.801629e-07     0.000018            6
# 11          0.111111              NaN  2.490337e-07     0.000018            6
# 12          0.235465      2594.005814  6.403723e-07     1.000000            6
# 13          0.353846              NaN  5.042932e-06     1.000000            7
# 14          0.353846              NaN  5.763351e-06     1.000000            7
# 15          0.282051     34320.692308  6.403723e-07     1.000000            6
# 16          0.309557              NaN  8.218112e-06     1.000000            5
# 17          0.166667        13.230769  1.259690e-02     0.075581            6
# 18          0.400000        33.000000  4.662005e-03     1.000000            5
# 19          0.166667         1.083333  1.538462e-01     0.923077            6
# 20          0.333333        55.846154  2.754821e-03     1.000000            6
# 21          0.166667         2.538462  5.050505e-03     0.393939            6
# 22          0.166667        13.230769  1.079734e-02     0.075581            6
# 23          0.282051     34320.692308  3.735505e-07     1.000000            6
# 24          0.166667         2.538462  6.565657e-02     0.393939            6
# 25          0.333333        55.846154  3.213958e-03     1.000000            6
# 26          0.166667         1.083333  1.318681e-01     0.923077            6
# 27          0.166667         1.083333  1.153846e-01     0.923077            6
# 28          0.166667        13.230769  1.259690e-02     0.075581            6
# 29          0.333333         5.000000  2.692308e-02     1.000000            6
# ..               ...              ...           ...          ...          ...
# 123         0.166667         2.538462  0.000000e+00     0.393939            6
# 124         0.200000        13.000000  9.615385e-03     0.076923            5
# 125         0.166667        60.500000  2.361275e-03     0.016529            6
# 126         0.166667        60.500000  2.066116e-03     0.016529            6
# 127         0.467949         4.220930  4.729109e-02     1.000000            6
# 128         0.436782        11.169231  1.205234e-02     1.000000            6
# 129         0.436782        11.169231  1.377410e-02     1.000000            6
# 130         0.333333        55.846154  2.295684e-04     1.000000            6
# 131         0.987234         1.692308  9.108127e-02     1.000000            5
# 132         1.000000              NaN  8.750000e-01     1.000000            7
# 133         0.166667        14.333333  9.966777e-03     0.069767            6
# 134         0.166667         5.416667  2.051282e-02     0.184615            6
# 135         0.166667         5.416667  2.307692e-02     0.184615            6
# 136         0.166667         1.083333  0.000000e+00     0.923077            6
# 137         0.200000        35.750000  3.108003e-03     0.027972            5
# 138         0.166667        14.333333  8.720930e-03     0.069767            6
# 139         0.142857         5.416667  2.051282e-02     0.184615            7
# 140         0.166667         5.416667  2.051282e-02     0.184615            6
# 141         0.166667         1.083333  0.000000e+00     0.923077            6
# 142         0.166667        35.750000  3.108003e-03     0.027972            6
# 143         0.272436         2.646154  5.159884e-02     0.377907            6
# 144         0.272436         2.646154  5.897010e-02     0.377907            6
# 145         0.166667        13.230769  0.000000e+00     0.075581            6
# 146         0.246154         2.494186  5.011655e-02     0.400932            5
# 147         1.000000              NaN  8.750000e-01     1.000000            7
# 148         0.333333         5.000000  1.923077e-03     1.000000            6
# 149         0.385057         6.600000  1.813002e-02     1.000000            6
# 150         0.333333         5.000000  2.197802e-03     1.000000            6
# 151         0.462069         6.600000  1.813002e-02     1.000000            5
# 152         0.400000        33.000000  2.913753e-04     1.000000            5
#
#                       dest  ground_truth  max_containment  max_contraction  \
# 0           crimeTypes.csv         False         1.000000     34320.692308
# 1         areaCrime__1.csv         False         0.969697              NaN
# 2           typeLoc__2.csv         False         1.000000              NaN
# 3        crimesByMonth.csv         False         1.000000     37180.750000
# 4           typeLoc__1.csv         False         1.000000              NaN
# 5         areaCrime__3.csv         False         0.969697              NaN
# 6    locationRecode__1.csv         False         1.000000      2594.005814
# 7               crimes.csv          True         1.000000              NaN
# 8         areaCrime__2.csv         False         0.969697              NaN
# 9              typeLoc.csv         False         1.000000              NaN
# 10    crimesByMonth__1.csv         False         0.666667              NaN
# 11    crimesByMonth__2.csv         False         0.666667              NaN
# 12           areaCrime.csv         False         1.000000      2594.005814
# 13      typeOutcome__1.csv         False         1.000000              NaN
# 14         typeOutcome.csv          True         1.000000              NaN
# 15       crimeTypes__1.csv         False         1.000000     34320.692308
# 16          typeLoc__3.csv         False         1.000000              NaN
# 17        areaCrime__1.csv         False         1.000000        13.230769
# 18          typeLoc__2.csv         False         1.000000        33.000000
# 19       crimesByMonth.csv         False         1.000000         1.083333
# 20          typeLoc__1.csv         False         1.000000        55.846154
# 21        areaCrime__3.csv         False         1.000000         2.538462
# 22   locationRecode__1.csv         False         1.000000        13.230769
# 23              crimes.csv          True         1.000000     34320.692308
# 24        areaCrime__2.csv         False         1.000000         2.538462
# 25             typeLoc.csv         False         1.000000        55.846154
# 26    crimesByMonth__1.csv         False         1.000000         1.083333
# 27    crimesByMonth__2.csv         False         1.000000         1.083333
# 28           areaCrime.csv         False         1.000000        13.230769
# 29      typeOutcome__1.csv         False         1.000000         5.000000
# ..                     ...           ...              ...              ...
# 123      crimeTypes__1.csv         False         1.000000         2.538462
# 124         typeLoc__3.csv         False         1.000000        13.000000
# 125   crimesByMonth__1.csv         False         1.000000        60.500000
# 126   crimesByMonth__2.csv         False         1.000000        60.500000
# 127          areaCrime.csv         False         1.000000         4.220930
# 128     typeOutcome__1.csv         False         1.000000        11.169231
# 129        typeOutcome.csv         False         1.000000        11.169231
# 130      crimeTypes__1.csv         False         1.000000        55.846154
# 131         typeLoc__3.csv         False         1.000000         1.692308
# 132   crimesByMonth__2.csv          True         1.000000              NaN
# 133          areaCrime.csv         False         1.000000        14.333333
# 134     typeOutcome__1.csv         False         1.000000         5.416667
# 135        typeOutcome.csv         False         1.000000         5.416667
# 136      crimeTypes__1.csv         False         1.000000         1.083333
# 137         typeLoc__3.csv         False         1.000000        35.750000
# 138          areaCrime.csv         False         1.000000        14.333333
# 139     typeOutcome__1.csv         False         1.000000         5.416667
# 140        typeOutcome.csv         False         1.000000         5.416667
# 141      crimeTypes__1.csv         False         1.000000         1.083333
# 142         typeLoc__3.csv         False         1.000000        35.750000
# 143     typeOutcome__1.csv         False         1.000000         2.646154
# 144        typeOutcome.csv         False         1.000000         2.646154
# 145      crimeTypes__1.csv         False         1.000000        13.230769
# 146         typeLoc__3.csv         False         1.000000         2.494186
# 147        typeOutcome.csv          True         1.000000              NaN
# 148      crimeTypes__1.csv         False         1.000000         5.000000
# 149         typeLoc__3.csv         False         1.000000         6.600000
# 150      crimeTypes__1.csv         False         1.000000         5.000000
# 151         typeLoc__3.csv         False         1.000000         6.600000
# 152         typeLoc__3.csv         False         1.000000        33.000000
#
#      min_containment  min_contraction operation                source  \
# 0           0.000000     34320.692308       NaN         crimes__2.csv
# 1           0.000000              NaN       NaN         crimes__2.csv
# 2           0.000000              NaN       NaN         crimes__2.csv
# 3           0.000000     37180.750000       NaN         crimes__2.csv
# 4           0.000000              NaN       NaN         crimes__2.csv
# 5           0.000000              NaN       NaN         crimes__2.csv
# 6           0.000000      2594.005814       NaN         crimes__2.csv
# 7           1.000000              NaN     apply         crimes__2.csv
# 8           0.000000              NaN       NaN         crimes__2.csv
# 9           0.000000              NaN       NaN         crimes__2.csv
# 10          0.000000              NaN       NaN         crimes__2.csv
# 11          0.000000              NaN       NaN         crimes__2.csv
# 12          0.000000      2594.005814       NaN         crimes__2.csv
# 13          0.000000              NaN       NaN         crimes__2.csv
# 14          0.000000              NaN   groupby         crimes__2.csv
# 15          0.000000     34320.692308       NaN         crimes__2.csv
# 16          0.000000              NaN       NaN         crimes__2.csv
# 17          0.000000        13.230769       NaN        crimeTypes.csv
# 18          0.000000        33.000000       NaN        crimeTypes.csv
# 19          0.000000         1.083333       NaN        crimeTypes.csv
# 20          0.000000        55.846154       NaN        crimeTypes.csv
# 21          0.000000         2.538462       NaN        crimeTypes.csv
# 22          0.000000        13.230769       NaN        crimeTypes.csv
# 23          0.000000     34320.692308   groupby        crimeTypes.csv
# 24          0.000000         2.538462       NaN        crimeTypes.csv
# 25          0.000000        55.846154       NaN        crimeTypes.csv
# 26          0.000000         1.083333       NaN        crimeTypes.csv
# 27          0.000000         1.083333       NaN        crimeTypes.csv
# 28          0.000000        13.230769       NaN        crimeTypes.csv
# 29          0.000000         5.000000       NaN        crimeTypes.csv
# ..               ...              ...       ...                   ...
# 123         0.000000         2.538462       NaN      areaCrime__2.csv
# 124         0.000000        13.000000       NaN      areaCrime__2.csv
# 125         0.000000        60.500000       NaN           typeLoc.csv
# 126         0.000000        60.500000       NaN           typeLoc.csv
# 127         0.000000         4.220930       NaN           typeLoc.csv
# 128         0.000000        11.169231       NaN           typeLoc.csv
# 129         0.000000        11.169231       NaN           typeLoc.csv
# 130         0.000000        55.846154       NaN           typeLoc.csv
# 131         0.978723         1.692308       NaN           typeLoc.csv
# 132         1.000000              NaN     apply  crimesByMonth__1.csv
# 133         0.000000        14.333333       NaN  crimesByMonth__1.csv
# 134         0.000000         5.416667       NaN  crimesByMonth__1.csv
# 135         0.000000         5.416667       NaN  crimesByMonth__1.csv
# 136         0.000000         1.083333       NaN  crimesByMonth__1.csv
# 137         0.000000        35.750000       NaN  crimesByMonth__1.csv
# 138         0.000000        14.333333       NaN  crimesByMonth__2.csv
# 139         0.000000         5.416667       NaN  crimesByMonth__2.csv
# 140         0.000000         5.416667       NaN  crimesByMonth__2.csv
# 141         0.000000         1.083333       NaN  crimesByMonth__2.csv
# 142         0.000000        35.750000       NaN  crimesByMonth__2.csv
# 143         0.000000         2.646154       NaN         areaCrime.csv
# 144         0.000000         2.646154       NaN         areaCrime.csv
# 145         0.000000        13.230769       NaN         areaCrime.csv
# 146         0.000000         2.494186       NaN         areaCrime.csv
# 147         1.000000              NaN     apply    typeOutcome__1.csv
# 148         0.000000         5.000000       NaN    typeOutcome__1.csv
# 149         0.000000         6.600000       NaN    typeOutcome__1.csv
# 150         0.000000         5.000000       NaN       typeOutcome.csv
# 151         0.103448         6.600000       NaN       typeOutcome.csv
# 152         0.000000        33.000000       NaN     crimeTypes__1.csv
#
#      unique_cols
# 0              1
# 1              0
# 2              0
# 3              1
# 4              0
# 5              0
# 6              1
# 7              0
# 8              0
# 9              0
# 10             0
# 11             0
# 12             1
# 13             0
# 14             0
# 15             1
# 16             0
# 17             1
# 18             2
# 19             1
# 20             2
# 21             1
# 22             1
# 23             1
# 24             1
# 25             2
# 26             1
# 27             1
# 28             1
# 29             2
# ..           ...
# 123            1
# 124            1
# 125            1
# 126            1
# 127            2
# 128            1
# 129            1
# 130            2
# 131            1
# 132            0
# 133            1
# 134            1
# 135            1
# 136            1
# 137            1
# 138            1
# 139            1
# 140            1
# 141            1
# 142            1
# 143            1
# 144            1
# 145            1
# 146            1
# 147            0
# 148            2
# 149            1
# 150            2
# 151            1
# 152            2
#
# [153 rows x 14 columns]

# %%
def col_containment(df1, df2, colname, col2name=None):
    if(col2name==None):
        col2name = colname

    df1valset = set(df1[colname])
    df2valset = set(df2[col2name])

    return df1valset.intersection(df2valset) / len(df2valset)

# %%
col_containment(df_dict['crimes.csv'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5e557c70c57b> in <module>
# ----> 1 col_containment(df_dict['crimes.csv'])
#
# NameError: name 'df_dict' is not defined
