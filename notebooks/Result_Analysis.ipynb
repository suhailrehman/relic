# %%
import os
import sys
import inspect
import networkx as nx
import pandas as pd

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)

# %%
def get_precision_recall(G_truth, T_inferred):
    g_edge_set = set([frozenset((v1, v2)) for v1, v2 in G_truth.edges])
    t_edge_set = set([frozenset((v1, v2)) for v1, v2 in T_inferred.edges])

    correct = g_edge_set.intersection(t_edge_set)

    to_add = g_edge_set - t_edge_set
    to_remove = t_edge_set - g_edge_set

    try:
        precision = float(len(correct)) / len(t_edge_set)
        recall = float(len(correct)) / len(g_edge_set)
        f1 = 2 * ((precision * recall) / (precision + recall))
    except ZeroDivisionError as e:
        precision = 0.0
        recall = 0.0
        f1 = 0.0

    return {'Precision': precision,
            'Recall': recall,
            'F1': f1,
            'correct_edges': correct,
            'to_add': to_add,
            'to_remove': to_remove}

# %%
g_truth_file='/home/suhail/Scratch/mixed_results/combined_all_gt_fixed.pkl'
inferred_graph='/home/suhail/Scratch/mixed_results/inferred_graph.csv'
g_truth = nx.read_gpickle(g_truth_file)
g_inferred = nx.read_edgelist(inferred_graph)

# %%
results=get_precision_recall(g_truth, g_inferred)
results['F1']
# Out:
# 0.6055913978494624

# %%
fp_edges = results['to_remove']

all_fp_edge_data = []
for u,v in fp_edges:
    wf1, wf2 = u.split('_')[0], v.split('_')[0]
    u1, v1 = u.split('_')[1], v.split('_')[1]
    #print(wf1, wf2, g_inferred[u][v])
    e_dict = {
        'wf1': wf1,
        'wf2': wf2,
        'src': u1,
        'dst': v1,
        'edge': frozenset([u,v])
    }
    e_dict.update(g_inferred[u][v])
    all_fp_edge_data.append(e_dict)
    
fp_df = pd.DataFrame(all_fp_edge_data)

# %%
fp_df['cross_wf'] = fp_df['wf1'] != fp_df['wf2']
fp_df
# Out:
#     wf1 wf2      src      dst                      edge        weight  \
# 0    34  92  000.csv  004.csv  (34_000.csv, 92_004.csv)      1.000000
# 1    17  17  009.csv  011.csv  (17_009.csv, 17_011.csv)      1.000000
# 2    42  10  004.csv  008.csv  (42_004.csv, 10_008.csv)    337.000000
# 3    14  66  002.csv  002.csv  (14_002.csv, 66_002.csv)     18.000000
# 4    36  36  000.csv  006.csv  (36_000.csv, 36_006.csv)      1.000000
# ..   ..  ..      ...      ...                       ...           ...
# 599  40  40  004.csv  001.csv  (40_004.csv, 40_001.csv)      1.000000
# 600  95  95  002.csv  000.csv  (95_002.csv, 95_000.csv)      1.000000
# 601  45  45  005.csv  002.csv  (45_005.csv, 45_002.csv)  15180.000000
# 602  46  32  004.csv  000.csv  (46_004.csv, 32_000.csv)      0.117111
# 603  73  46  004.csv  013.csv  (46_013.csv, 73_004.csv)    685.000000
#
#             type   num  cross_wf
# 0        groupby  1071      True
# 1           join   444     False
# 2    containment   999      True
# 3        jaccard   987      True
# 4           join   443     False
# ..           ...   ...       ...
# 599         join   553     False
# 600         join   595     False
# 601      jaccard   719     False
# 602      jaccard   994      True
# 603  containment  1001      True
#
# [604 rows x 9 columns]

# %%
fp_df['type'].value_counts()
# Out:
# join           314
# jaccard        177
# containment     68
# pivot           25
# groupby         20
# Name: type, dtype: int64

# %%
fp_df['cross_wf'].value_counts()
# Out:
# False    553
# True      51
# Name: cross_wf, dtype: int64

# %%
fp_df.groupby('type').mean()
# Out:
#                   weight          num  cross_wf
# type
# containment  1134.810871   829.808824  0.617647
# groupby         0.320227  1059.150000  0.350000
# jaccard      4716.563342   376.943503  0.011299
# join            1.000000   467.541401  0.000000
# pivot           0.000000  1088.840000  0.000000
